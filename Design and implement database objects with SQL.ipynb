# %% [markdown]
# # [Introduction](https://learn.microsoft.com/en-us/training/modules/design-implement-database-objects/1-introduction/?ns-enrollment-type=learningpath&ns-enrollment-id=learn.wwl.design-develop-database-solutions)
