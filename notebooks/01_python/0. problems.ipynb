# %% [markdown]
# *Note: The code cells contain the most Pythonic, optimized 1-2 line solutions for rapid review and muscle memory building.*
#
# ---
#
# # 🟢 PART 1: EASY (1 - 100)
# *Focus: Syntax, Basic Data Structures, Control Flow, and Built-ins*
#
# **1. Swap two variables**
# *Hint: Use tuple unpacking.*
# ```python
# a, b = b, a
# ```
#
# **2. Celsius to Fahrenheit**
# *Hint: Use the standard formula.*
# ```python
# f = c * 9/5 + 32
# ```
#
# **3. Area of a circle**
# *Hint: Use `math.pi`.*
# ```python
# import math; a = math.pi * r**2
# ```
#
# **4. Euclidean distance**
# *Hint: Use `math.hypot`.*
# ```python
# import math; d = math.hypot(x2-x1, y2-y1)
# ```
#
# **5. Sum of digits**
# *Hint: Convert to string, iterate, and sum.*
# ```python
# sum(int(d) for d in str(n))
# ```
#
# **6. Reverse an integer mathematically**
# *Hint: Use modulo and floor division.*
# ```python
# rev = rev*10 + n%10; n //= 10
# ```
#
# **7. Seconds to H:M:S**
# *Hint: Use `divmod`.*
# ```python
# h, r = divmod(s, 3600); m, s = divmod(r, 60)
# ```
#
# **8. Leap year logic**
# *Hint: Divisible by 4, not 100, unless 400.*
# ```python
# y%4==0 and (y%100!=0 or y%400==0)
# ```
#
# **9. Compound interest**
# *Hint: Use exponentiation.*
# ```python
# p * (1 + r/100)**t
# ```
#
# **10. BMI Calculator**
# *Hint: Weight divided by height squared.*
# ```python
# int(w / h**2)
# ```
#
# **11. Check Even/Odd**
# *Hint: Modulo 2.*
# ```python
# n % 2 == 0
# ```
#
# **12. Max of three numbers**
# *Hint: Use the built-in `max`.*
# ```python
# max(a, b, c)
# ```
#
# **13. FizzBuzz (1 to 15)**
# *Hint: Check 15 first.*
# ```python
# if i%15==0: print("FizzBuzz")
# ```
#
# **14. Prime checker**
# *Hint: Check up to square root.*
# ```python
# all(n%i for i in range(2, int(n**0.5)+1))
# ```
#
# **15. Factorial**
# *Hint: Use `math.factorial`.*
# ```python
# import math; math.factorial(n)
# ```
#
# **16. Star triangle**
# *Hint: Multiply string by loop index.*
# ```python
# for i in range(1, n+1): print('*'*i)
# ```
#
# **17. GCD of two numbers**
# *Hint: Use `math.gcd`.*
# ```python
# import math; math.gcd(a, b)
# ```
#
# **18. LCM of two numbers**
# *Hint: Use `math.lcm`.*
# ```python
# import math; math.lcm(a, b)
# ```
#
# **19. Palindrome string**
# *Hint: Compare string to its reverse slice.*
# ```python
# s == s[::-1]
# ```
#
# **20. Count vowels**
# *Hint: Sum boolean matches.*
# ```python
# sum(1 for c in s.lower() if c in 'aeiou')
# ```
#
# **21. Reverse a string**
# *Hint: Slicing with step -1.*
# ```python
# s[::-1]
# ```
#
# **22. First unique character**
# *Hint: Use `next` and `count`.*
# ```python
# next((c for c in s if s.count(c)==1), None)
# ```
#
# **23. Title case**
# *Hint: Use string method.*
# ```python
# s.title()
# ```
#
# **24. Remove punctuation**
# *Hint: Use `str.replace` or `re`.*
# ```python
# s.replace('!', '').replace('.', '')
# ```
#
# **25. Word frequency**
# *Hint: Use `collections.Counter`.*
# ```python
# from collections import Counter; Counter(s.split())
# ```
#
# **26. Anagram checker**
# *Hint: Sort both strings.*
# ```python
# sorted(s1) == sorted(s2)
# ```
#
# **27. Replace spaces with hyphens**
# *Hint: Use `replace`.*
# ```python
# s.replace(' ', '-')
# ```
#
# **28. Longest word in sentence**
# *Hint: Use `max` with `key=len`.*
# ```python
# max(s.split(), key=len)
# ```
#
# **29. Extract email domain**
# *Hint: Split by '@'.*
# ```python
# email.split('@')[1]
# ```
#
# **30. Swap case**
# *Hint: Use string method.*
# ```python
# s.swapcase()
# ```
#
# **31. Extract and sum digits**
# *Hint: Use `isdigit`.*
# ```python
# sum(int(c) for c in s if c.isdigit())
# ```
#
# **32. Compress string (basic)**
# *Hint: Loop and count consecutive.*
# ```python
# # Loop through and track current char count
# ```
#
# **33. Mask phone number**
# *Hint: Use slicing and string multiplication.*
# ```python
# s[:2] + '*'*6 + s[-2:]
# ```
#
# **34. Manual Min/Max**
# *Hint: Iterate and track.*
# ```python
# min_val = min(lst) # or loop
# ```
#
# **35. Reverse list in-place**
# *Hint: Use list method.*
# ```python
# lst.reverse()
# ```
#
# **36. Deduplicate preserving order**
# *Hint: Use `dict.fromkeys`.*
# ```python
# list(dict.fromkeys(lst))
# ```
#
# **37. Rotate list right by k**
# *Hint: Use slicing.*
# ```python
# lst[-k:] + lst[:-k]
# ```
#
# **38. Move zeros to end**
# *Hint: Sort by boolean condition.*
# ```python
# lst.sort(key=lambda x: x==0)
# ```
#
# **39. Second largest element**
# *Hint: Convert to set, sort, index.*
# ```python
# sorted(set(lst))[-2]
# ```
#
# **40. List intersection**
# *Hint: Use list comprehension and `in`.*
# ```python
# [x for x in l1 if x in l2]
# ```
#
# **41. Merge two sorted lists**
# *Hint: Concatenate and sort.*
# ```python
# sorted(l1 + l2)
# ```
#
# **42. Flatten 2D matrix**
# *Hint: Nested list comprehension.*
# ```python
# [x for sub in m for x in sub]
# ```
#
# **43. List of squares**
# *Hint: List comprehension.*
# ```python
# [x**2 for x in range(1, 21)]
# ```
#
# **44. Filter words containing 'a'**
# *Hint: Comprehension with `in`.*
# ```python
# [w for w in lst if 'a' in w]
# ```
#
# **45. Two sum pairs (brute)**
# *Hint: Nested loops/comprehension.*
# ```python
# [(a,b) for a in l for b in l if a+b==t]
# ```
#
# **46. Product of list**
# *Hint: Use `math.prod`.*
# ```python
# import math; math.prod(lst)
# ```
#
# **47. Split even/odd**
# *Hint: Two comprehensions.*
# ```python
# e=[x for x in l if x%2==0]; o=[x for x in l if x%2!=0]
# ```
#
# **48. Chunk list**
# *Hint: Slicing with step.*
# ```python
# [lst[i:i+n] for i in range(0, len(lst), n)]
# ```
#
# **49. Max length string in list**
# *Hint: `max` with `key=len`.*
# ```python
# max(lst, key=len)
# ```
#
# **50. Remove empty strings**
# *Hint: Filter by truthiness.*
# ```python
# [s for s in lst if s]
# ```
#
# **51. Cumulative sum**
# *Hint: Use `itertools.accumulate`.*
# ```python
# import itertools; list(itertools.accumulate(lst))
# ```
#
# **52. Matrix diagonal sum**
# *Hint: Index `i, i`.*
# ```python
# sum(m[i][i] for i in range(len(m)))
# ```
#
# **53. Parallel list addition**
# *Hint: Use `zip`.*
# ```python
# [a+b for a,b in zip(l1, l2)]
# ```
#
# **54. Tuple unpacking**
# *Hint: Direct assignment.*
# ```python
# a, b, c, d = t
# ```
#
# **55. Find duplicates in tuple**
# *Hint: Use `count`.*
# ```python
# set(x for x in t if t.count(x)>1)
# ```
#
# **56. Sort list of tuples by 2nd element**
# *Hint: Use `lambda` in `sorted`.*
# ```python
# sorted(lst, key=lambda x: x[1])
# ```
#
# **57. Check if tuple is homogeneous**
# *Hint: Convert to set.*
# ```python
# len(set(t)) == 1
# ```
#
# **58. Tuple of chars to string**
# *Hint: Use `join`.*
# ```python
# "".join(t)
# ```
#
# **59. Element-wise tuple sum**
# *Hint: Use `zip`.*
# ```python
# tuple(a+b for a,b in zip(t1, t2))
# ```
#
# **60. Min/Max of tuple**
# *Hint: Built-in functions.*
# ```python
# min(t), max(t)
# ```
#
# **61. Remove empty tuples from list**
# *Hint: Filter by truthiness.*
# ```python
# [t for t in lst if t]
# ```
#
# **62. Tuple of pairs to dict**
# *Hint: Pass to `dict()`.*
# ```python
# dict(t)
# ```
#
# **63. Middle slice of tuple**
# *Hint: Standard slicing.*
# ```python
# t[2:5]
# ```
#
# **64. Intersection of 3 lists**
# *Hint: Convert to sets and use `&`.*
# ```python
# set(l1) & set(l2) & set(l3)
# ```
#
# **65. Symmetric difference**
# *Hint: Use `^` operator.*
# ```python
# s1 ^ s2
# ```
#
# **66. Subset check**
# *Hint: Use `<=` operator.*
# ```python
# s1 <= s2
# ```
#
# **67. Safe discard from set**
# *Hint: Use `discard` instead of `remove`.*
# ```python
# s.discard(x)
# ```
#
# **68. Set difference**
# *Hint: Use `-` operator.*
# ```python
# s1 - s2
# ```
#
# **69. Disjoint check**
# *Hint: Use `isdisjoint`.*
# ```python
# s1.isdisjoint(s2)
# ```
#
# **70. Count unique characters**
# *Hint: Length of set.*
# ```python
# len(set(s))
# ```
#
# **71. Find missing numbers**
# *Hint: Set subtraction.*
# ```python
# set(range(1,11)) - set(lst)
# ```
#
# **72. Frozenset immutability test**
# *Hint: Try/Except block.*
# ```python
# try: fs.add(1)
# except AttributeError: pass
# ```
#
# **73. Mass union of sets**
# *Hint: Unpack with `*`.*
# ```python
# set().union(*sets)
# ```
#
# **74. Merge dictionaries**
# *Hint: Use `update` or `|`.*
# ```python
# d1 | d2
# ```
#
# **75. Sort dict by values**
# *Hint: Sort `items()`.*
# ```python
# dict(sorted(d.items(), key=lambda x: x[1]))
# ```
#
# **76. Dict comprehension (cubes)**
# *Hint: `{k:v for ...}`.*
# ```python
# {x: x**3 for x in range(1,11)}
# ```
#
# **77. Invert dictionary**
# *Hint: Swap k and v.*
# ```python
# {v: k for k, v in d.items()}
# ```
#
# **78. Key with max value**
# *Hint: `max` with `key=d.get`.*
# ```python
# max(d, key=d.get)
# ```
#
# **79. Group words by first letter**
# *Hint: Use `setdefault`.*
# ```python
# d.setdefault(w[0], []).append(w)
# ```
#
# **80. Character frequency**
# *Hint: Use `Counter`.*
# ```python
# from collections import Counter; Counter(s)
# ```
#
# **81. Zip lists to dict**
# *Hint: `dict(zip())`.*
# ```python
# dict(zip(keys, vals))
# ```
#
# **82. Safe dict deletion**
# *Hint: Use `pop` with default.*
# ```python
# d.pop(k, None)
# ```
#
# **83. Check if value exists in dict**
# *Hint: Check `.values()`.*
# ```python
# v in d.values()
# ```
#
# **84. Create nested dict**
# *Hint: Nested brackets.*
# ```python
# d = {'s1': {'math': 90}}
# ```
#
# **85. Nested dict averages**
# *Hint: Comprehension over values.*
# ```python
# {k: sum(v.values())/len(v) for k,v in d.items()}
# ```
#
# **86. Filter dict by threshold**
# *Hint: Dict comprehension.*
# ```python
# {k:v for k,v in d.items() if v > 10}
# ```
#
# **87. Zip unequal lists**
# *Hint: Use `itertools.zip_longest`.*
# ```python
# from itertools import zip_longest; list(zip_longest(a,b))
# ```
#
# **88. Phonebook CLI loop**
# *Hint: `while True` with `input`.*
# ```python
# while True: cmd=input()
# ```
#
# **89. Check memory address**
# *Hint: Use `id()`.*
# ```python
# id(a) == id(b)
# ```
#
# **90. Identity vs Equality**
# *Hint: Use `is`.*
# ```python
# a is b
# ```
#
# **91. Proper None check**
# *Hint: Use `is None`.*
# ```python
# if x is None: pass
# ```
#
# **92. Shallow copy list**
# *Hint: Use `.copy()`.*
# ```python
# b = a.copy()
# ```
#
# **93. Deep copy nested list**
# *Hint: Use `copy.deepcopy`.*
# ```python
# import copy; b = copy.deepcopy(a)
# ```
#
# **94. Check mutability**
# *Hint: Check against types.*
# ```python
# isinstance(x, (list, dict, set))
# ```
#
# **95. Boolean arithmetic**
# *Hint: Bools are ints.*
# ```python
# True + True == 2
# ```
#
# **96. Float precision check**
# *Hint: Use `math.isclose`.*
# ```python
# math.isclose(0.1+0.2, 0.3)
# ```
#
# **97. Check falsy values**
# *Hint: Use `not bool()`.*
# ```python
# not bool([])
# ```
#
# **98. String to int conversion**
# *Hint: Use `int()`.*
# ```python
# int("100")
# ```
#
# **99. String truthiness trap**
# *Hint: Non-empty strings are True.*
# ```python
# bool("False") == True
# ```
#
# **100. Safe division**
# *Hint: Try/Except ZeroDivisionError.*
# ```python
# try: return a/b
# except ZeroDivisionError: return 0
# ```
#
# ---
#
# # 🟡 PART 2: MODERATE (101 - 200)
# *Focus: Algorithms, Data Cleaning, Comprehensions, and Edge Cases*
#
# **101. Extract digits without string conversion**
# *Hint: Use math modulo in a while loop.*
# ```python
# while n: d.append(n%10); n//=10
# ```
#
# **102. Custom power function**
# *Hint: Multiply in a loop.*
# ```python
# res=1;
# for _ in range(abs(exp)): res*=base
# ```
#
# **103. Check if all elements of L1 are in L2**
# *Hint: Use `all()`.*
# ```python
# all(x in l2 for x in l1)
# ```
#
# **104. Floor division vs truncation**
# *Hint: `//` rounds to negative infinity.*
# ```python
# -7//3 == -3; int(-7/3) == -2
# ```
#
# **105. Simple string expression evaluator**
# *Hint: Use `eval()` (with caution).*
# ```python
# eval("2+3*4")
# ```
#
# **106. Bitwise operations dictionary**
# *Hint: Map operators to results.*
# ```python
# {'&': a&b, '|': a|b, '^': a^b}
# ```
#
# **107. Password validator**
# *Hint: Use `any()` with string methods.*
# ```python
# any(c.isdigit() for c in p) and len(p)>=8
# ```
#
# **108. Range overlap checker**
# *Hint: Compare max of starts to min of ends.*
# ```python
# max(s1, s2) <= min(e1, e2)
# ```
#
# **109. Ternary grade assignment**
# *Hint: Chain ternary operators.*
# ```python
# "A" if s>=90 else "B" if s>=80 else "C"
# ```
#
# **110. Manual list rotation**
# *Hint: Pop and insert.*
# ```python
# for _ in range(k): lst.insert(0, lst.pop())
# ```
#
# **111. O(N) Deduplication preserving order**
# *Hint: Use a seen set in comprehension.*
# ```python
# seen=set(); [x for x in l if not (x in seen or seen.add(x))]
# ```
#
# **112. Deep flatten any nested list**
# *Hint: Recursive generator.*
# ```python
# def f(l):
#     for x in l: yield from (f(x) if isinstance(x,list) else [x])
# ```
#
# **113. Sliding window maximum**
# *Hint: Use `collections.deque`.*
# ```python
# from collections import deque; # Maintain decreasing monotonic queue
# ```
#
# **114. O(N+M) List intersection**
# *Hint: Convert one list to set first.*
# ```python
# [x for x in l1 if x in set(l2)]
# ```
#
# **115. Bubble sort implementation**
# *Hint: Nested loops swapping adjacent.*
# ```python
# for i in range(n):
#     for j in range(n-i-1): # swap if out of order
# ```
#
# **116. Two Sum O(N)**
# *Hint: Store complements in a dictionary.*
# ```python
# seen={};
# for i,x in enumerate(l):
#     if t-x in seen: return (seen[t-x], i)
# ```
#
# **117. Move zeros in-place O(N)**
# *Hint: Two pointers.*
# ```python
# idx=0;
# for x in l:
#     if x!=0: l[idx]=x; idx+=1
# ```
#
# **118. Generator for list chunking**
# *Hint: Use `yield`.*
# ```python
# for i in range(0,len(l),n): yield l[i:i+n]
# ```
#
# **119. In-place running sum**
# *Hint: Add previous index to current.*
# ```python
# for i in range(1,len(l)): l[i]+=l[i-1]
# ```
#
# **120. Majority element**
# *Hint: Use `Counter.most_common`.*
# ```python
# Counter(l).most_common(1)[0][0]
# ```
#
# **121. List difference preserving order**
# *Hint: Comprehension with set lookup.*
# ```python
# [x for x in l1 if x not in set(l2)]
# ```
#
# **122. Max subarray sum (Kadane's)**
# *Hint: Track current and max sum.*
# ```python
# cur=mx=0;
# for x in l: cur=max(x,cur+x); mx=max(mx,cur)
# ```
#
# **123. Cycle detection in list**
# *Hint: Floyd's Tortoise and Hare.*
# ```python
# slow=fast=head;
# while fast and fast.next: slow=slow.next; fast=fast.next.next
# ```
#
# **124. Merge two sorted lists O(N)**
# *Hint: Two pointers.*
# ```python
# while i<len(a) and j<len(b): # compare and append
# ```
#
# **125. Parse CSV string**
# *Hint: Use `csv` module and `io.StringIO`.*
# ```python
# import csv, io; list(csv.reader(io.StringIO(s)))
# ```
#
# **126. Palindrome ignoring punctuation**
# *Hint: Use `re.sub` to clean.*
# ```python
# import re; s=re.sub(r'\W','',s).lower(); s==s[::-1]
# ```
#
# **127. O(N) Anagram check**
# *Hint: Compare Counters.*
# ```python
# Counter(s1) == Counter(s2)
# ```
#
# **128. String compression (itertools)**
# *Hint: Use `groupby`.*
# ```python
# from itertools import groupby; "".join(k+str(len(list(g))) for k,g in groupby(s))
# ```
#
# **129. Word frequency dictionary**
# *Hint: Use `get` with default.*
# ```python
# d={};
# for w in s.split(): d[w]=d.get(w,0)+1
# ```
#
# **130. Parse URL components**
# *Hint: Use `urllib.parse`.*
# ```python
# from urllib.parse import urlparse; urlparse(url)
# ```
#
# **131. Reverse words in string**
# *Hint: Split, reverse, join.*
# ```python
# " ".join(s.split()[::-1])
# ```
#
# **132. Longest common prefix**
# *Hint: Use `zip(*strs)`.*
# ```python
# "".join(c[0] for c in zip(*strs) if len(set(c))==1)
# ```
#
# **133. Valid email regex**
# *Hint: Use `re.match`.*
# ```python
# bool(re.match(r'^[\w.-]+@[\w.-]+\.\w+$', e))
# ```
#
# **134. String to Integer (atoi)**
# *Hint: Loop and multiply by 10.*
# ```python
# res=0;
# for c in s.strip(): res=res*10+int(c)
# ```
#
# **135. Replace multiple substrings**
# *Hint: Use `re.sub` with dict.*
# ```python
# re.sub('|'.join(rep), lambda m: rep[m.group(0)], s)
# ```
#
# **136. CamelCase to snake_case**
# *Hint: Regex lookahead.*
# ```python
# re.sub(r'(?<!^)(?=[A-Z])', '_', s).lower()
# ```
#
# **137. Sort string by frequency**
# *Hint: `sorted` with custom key.*
# ```python
# "".join(sorted(s, key=lambda c: (-s.count(c), c)))
# ```
#
# **138. Find all substring indices**
# *Hint: List comp with `startswith`.*
# ```python
# [i for i in range(len(t)) if t.startswith(p, i)]
# ```
#
# **139. Wrap text to width**
# *Hint: Use `textwrap`.*
# ```python
# import textwrap; textwrap.fill(s, width)
# ```
#
# **140. FizzBuzz without modulo**
# *Hint: Use counters.*
# ```python
# c3=c5=0; c3+=1;
# if c3==3: print("Fizz"); c3=0
# ```
#
# **141. Diamond star pattern**
# *Hint: Use absolute value.*
# ```python
# for i in range(-n,n): print('*'*(n-abs(i)))
# ```
#
# **142. Sieve of Eratosthenes**
# *Hint: Boolean array marking.*
# ```python
# is_p=[True]*n;
# for i in range(2,int(n**0.5)): # mark multiples False
# ```
#
# **143. Fibonacci generator**
# *Hint: Yield and swap.*
# ```python
# a,b=0,1;
# while True: yield a; a,b=b,a+b
# ```
#
# **144. Pascal's triangle**
# *Hint: Zip shifted rows.*
# ```python
# row=[1];
# for _ in range(n): yield row; row=[x+y for x,y in zip([0]+row, row+[0])]
# ```
#
# **145. Spiral matrix generation**
# *Hint: Maintain boundaries.*
# ```python
# top,bot,left,right = 0,n-1,0,n-1; # loop and shrink
# ```
#
# **146. Enumerate with condition**
# *Hint: List comp over enumerate.*
# ```python
# [i for i,x in enumerate(l) if cond(x)]
# ```
#
# **147. Zip with fill value**
# *Hint: Use `itertools.zip_longest`.*
# ```python
# from itertools import zip_longest; list(zip_longest(a,b,fillvalue=0))
# ```
#
# **148. Group by key function**
# *Hint: Use `itertools.groupby`.*
# ```python
# from itertools import groupby; {k:list(v) for k,v in groupby(sorted(l, key=f), f)}
# ```
#
# **149. Cartesian product**
# *Hint: Use `itertools.product`.*
# ```python
# from itertools import product; list(product(a,b))
# ```
#
# **150. Search nested list**
# *Hint: Recursive DFS.*
# ```python
# def find(l, t, path=()): # yield path if found
# ```
#
# **151. Safe removal while iterating**
# *Hint: Iterate over a slice copy.*
# ```python
# for x in l[:]:
#     if cond: l.remove(x)
# ```
#
# **152. Two sum using set**
# *Hint: Check complement in set.*
# ```python
# seen=set();
# for x in l:
#     if t-x in seen: return True
# ```
#
# **153. Word index dictionary**
# *Hint: Use `enumerate` and `setdefault`.*
# ```python
# d={};
# for i,w in enumerate(t.split()): d.setdefault(w,[]).append(i)
# ```
#
# **154. Linear search with else**
# *Hint: Use `for...else` block.*
# ```python
# for x in l:
#     if x==t: break
# else: print("Not found")
# ```
#
# **155. Matrix transpose**
# *Hint: Unpack with `zip(*m)`.*
# ```python
# [list(x) for x in zip(*m)]
# ```
#
# **156. Conditional mapping**
# *Hint: Ternary in comprehension.*
# ```python
# [x**2 if x%2==0 else x**3 for x in l]
# ```
#
# **157. Multiplication table**
# *Hint: Nested comprehension.*
# ```python
# [[i*j for j in range(1,n+1)] for i in range(1,n+1)]
# ```
#
# **158. Vowel word lengths**
# *Hint: `any` in comprehension.*
# ```python
# [len(w) for w in l if any(v in w for v in 'aeiou')]
# ```
#
# **159. Dict comp properties**
# *Hint: Nested dict in comp.*
# ```python
# {x: {'sq':x**2, 'cb':x**3} for x in range(1,n)}
# ```
#
# **160. Common chars in multiple strings**
# *Hint: Set intersection.*
# ```python
# set.intersection(*[set(s) for s in strings])
# ```
#
# **161. Flatten 2D with condition**
# *Hint: Add `if` to nested comp.*
# ```python
# [x for r in m for x in r if x>0]
# ```
#
# **162. List of dicts to dict of lists**
# *Hint: Comprehension over keys.*
# ```python
# {k: [d[k] for d in l] for k in l[0]}
# ```
#
# **163. Pythagorean triples**
# *Hint: 3-loop comprehension.*
# ```python
# [(a,b,c) for a in range(n) for b in range(a,n) for c in range(b,n) if a*a+b*b==c*c]
# ```
#
# **164. Word length distribution**
# *Hint: Group by `len(w)`.*
# ```python
# {l: [w for w in s.split() if len(w)==l] for l in set(len(w) for w in s.split())}
# ```
#
# **165. Data structure recommender**
# *Hint: If/elif logic.*
# ```python
# if unique and not ordered: return "Set"
# ```
#
# **166. Benchmark List vs Set**
# *Hint: Use `timeit`.*
# ```python
# import timeit; timeit.timeit('9999 in s', globals=globals())
# ```
#
# **167. Tuple vs List memory**
# *Hint: Use `sys.getsizeof`.*
# ```python
# import sys; sys.getsizeof(l) - sys.getsizeof(t)
# ```
#
# **168. Dict merge 3 ways**
# *Hint: `|`, `**`, `update`.*
# ```python
# d1|d2; {**d1, **d2}; d1.update(d2)
# ```
#
# **169. Set purchases analysis**
# *Hint: Intersection and difference.*
# ```python
# both = A&B; onlyA = A-B
# ```
#
# **170. Custom hashable class**
# *Hint: Implement `__hash__`.*
# ```python
# def __hash__(self): return hash((self.x, self.y))
# ```
#
# **171. LRU Cache implementation**
# *Hint: Use `OrderedDict`.*
# ```python
# from collections import OrderedDict; # move_to_end on get
# ```
#
# **172. AutoDict (defaultdict)**
# *Hint: Override `__missing__`.*
# ```python
# def __missing__(self, k): self[k]=self.default(); return self[k]
# ```
#
# **173. Longest subset chain**
# *Hint: Sort by length, check `<=`.*
# ```python
# sorted(sets, key=len); # check all(s1<=s2)
# ```
#
# **174. Dedup benchmark**
# *Hint: Compare `set` vs `dict.fromkeys`.*
# ```python
# list(set(l)) # vs list(dict.fromkeys(l))
# ```
#
# **175. Grade analyzer**
# *Hint: Comprehension for averages.*
# ```python
# avg = sum(s['scores'])/len(s['scores'])
# ```
#
# **176. Text analysis pipeline**
# *Hint: `re.findall`.*
# ```python
# re.findall(r'\b\w+\b', s.lower())
# ```
#
# **177. Social network mutuals**
# *Hint: Dict of sets intersection.*
# ```python
# graph[u].add(v); mutual = graph[u]&graph[v]
# ```
#
# **178. Inventory system**
# *Hint: Class with dict.*
# ```python
# class Inv: def add(self, i, q): self.d[i]+=q
# ```
#
# **179. Contact manager**
# *Hint: Class with search dict.*
# ```python
# class CM: def search(self, q): return self.d.get(q)
# ```
#
# **180. Reverse linked list**
# *Hint: Three pointers.*
# ```python
# prev, curr = None, head;
# while curr: curr.next, prev, curr = prev, curr, curr.next
# ```
#
# **181. Valid parentheses**
# *Hint: Use a stack.*
# ```python
# stack=[];
# for c in s:
#     if c=='(': stack.append(c)
# ```
#
# **182. Min stack O(1)**
# *Hint: Store tuples `(val, min_so_far)`.*
# ```python
# stack.append((val, min(val, stack[-1][1])))
# ```
#
# **183. Evaluate RPN**
# *Hint: Stack for operands.*
# ```python
# for t in tokens:
#     if t in '+-*/': b=stack.pop(); a=stack.pop()
# ```
#
# **184. Daily temperatures**
# *Hint: Monotonic decreasing stack.*
# ```python
# stack=[];
# for i,t in enumerate(temps):
#     while stack and temps[stack[-1]]<t: # pop and record
# ```
#
# **185. Trie implementation**
# *Hint: Nested dicts.*
# ```python
# class TrieNode: def __init__(self): self.children={}
# ```
#
# **186. BFS graph traversal**
# *Hint: Use `deque`.*
# ```python
# q=deque([start]);
# while q: node=q.popleft()
# ```
#
# **187. DFS graph traversal**
# *Hint: Recursion with visited set.*
# ```python
# def dfs(node, visited): visited.add(node)
# ```
#
# **188. Binary search**
# *Hint: `l, r, mid`.*
# ```python
# l,r=0,len(a)-1;
# while l<=r: mid=(l+r)//2
# ```
#
# **189. Merge intervals**
# *Hint: Sort by start time.*
# ```python
# intervals.sort();
# for i in intervals:
#     if not res or res[-1][1]<i[0]: res.append(i)
# ```
#
# **190. Top K frequent elements**
# *Hint: Use `heapq.nlargest`.*
# ```python
# import heapq; heapq.nlargest(k, count.keys(), key=count.get)
# ```
#
# **191. Find median from stream**
# *Hint: Max-heap and Min-heap.*
# ```python
# max_heap, min_heap = [], []
# ```
#
# **192. Word break**
# *Hint: 1D DP array.*
# ```python
# dp=[False]*(n+1); dp[0]=True;
# for i in range(1,n+1): # check substrings
# ```
#
# **193. Coin change**
# *Hint: DP array initialized to infinity.*
# ```python
# dp=[float('inf')]*(amt+1); dp[0]=0;
# for c in coins: # update dp
# ```
#
# **194. Longest increasing subsequence**
# *Hint: O(N^2) DP or O(N log N) patience sorting.*
# ```python
# dp=[1]*n;
# for i in range(1,n):
#     for j in range(i): # update dp[i]
# ```
#
# **195. 0/1 Knapsack**
# *Hint: 2D DP table.*
# ```python
# dp=[[0]*(W+1) for _ in range(n+1)]
# ```
#
# **196. Edit distance**
# *Hint: 2D DP, min of 3 operations.*
# ```python
# dp[i][j] = 1 + min(dp[i-1][j], dp[i][j-1], dp[i-1][j-1])
# ```
#
# **197. Max product subarray**
# *Hint: Track min and max at each step.*
# ```python
# # keep track of min and max at each step
# ```
#
# **198. Partition equal subset sum**
# *Hint: Subset sum to `total_sum // 2`.*
# ```python
# # subset sum to total_sum // 2
# ```
#
# **199. Longest palindromic substring**
# *Hint: Expand around center.*
# ```python
# for i in range(n): expand(i,i); expand(i,i+1)
# ```
#
# **200. Regex exact match**
# *Hint: Use `re.fullmatch`.*
# ```python
# re.fullmatch(pattern, s)
# ```
#
# ---
#
# # 🔴 PART 3: HARD (201 - 300)
# *Focus: Advanced Algorithms, System Design, OOP, and LeetCode Hard*
#
# **201. LRU Cache O(1)**
# *Hint: Doubly Linked List + Hash Map.*
# ```python
# class Node: pass # Combine with OrderedDict for Pythonic O(1)
# ```
#
# **202. LFU Cache**
# *Hint: Dict + Freq Dict of Doubly Linked Lists.*
# ```python
# class LFUCache: pass # Track min_freq
# ```
#
# **203. Serialize Binary Tree**
# *Hint: Preorder traversal with null markers.*
# ```python
# def serialize(root): # yield vals or '#'
# ```
#
# **204. Deserialize Binary Tree**
# *Hint: Iterator over tokens.*
# ```python
# def deserialize(data): # build recursively
# ```
#
# **205. Alien Dictionary**
# *Hint: Topological sort on character graph.*
# ```python
# # build graph, indegree, Kahn's algo
# ```
#
# **206. Course Schedule (Cycle Detection)**
# *Hint: DFS with 3 colors.*
# ```python
# # DFS with colors (white, gray, black)
# ```
#
# **207. Word Ladder**
# *Hint: BFS with character mutations.*
# ```python
# queue=deque([(start, 1)]); # mutate 1 char at a time
# ```
#
# **208. Network Delay Time**
# *Hint: Dijkstra's algorithm.*
# ```python
# import heapq; pq=[(0, src)] # track max time
# ```
#
# **209. Cheapest Flights K Stops**
# *Hint: Bellman-Ford or modified Dijkstra.*
# ```python
# dp = [inf]*n; dp[src]=0;
# for _ in range(K+1): # relax edges
# ```
#
# **210. Swim in Rising Water**
# *Hint: Dijkstra on grid.*
# ```python
# heapq.heappush(pq, (grid[0][0], 0, 0))
# ```
#
# **211. Trapping Rain Water**
# *Hint: Two pointers, track left/right max.*
# ```python
# l,r=0,n-1; lmax=rmax=0;
# while l<r: # move pointer with smaller max
# ```
#
# **212. Largest Rectangle in Histogram**
# *Hint: Monotonic increasing stack.*
# ```python
# stack=[];
# for i,h in enumerate(heights): # pop and calculate area
# ```
#
# **213. Maximal Rectangle**
# *Hint: Apply Q212 to each row.*
# ```python
# # treat each row as base of histogram
# ```
#
# **214. Median of Two Sorted Arrays**
# *Hint: Binary search on smaller array.*
# ```python
# # partition X and Y such that left halves == right halves
# ```
#
# **215. Kth Largest Element**
# *Hint: Quickselect algorithm.*
# ```python
# # random pivot, partition, recurse
# ```
#
# **216. Merge K Sorted Lists**
# *Hint: Min-heap of list heads.*
# ```python
# import heapq; list(heapq.merge(*lists))
# ```
#
# **217. Sliding Window Maximum**
# *Hint: Monotonic deque.*
# ```python
# dq=deque();
# for i,x in enumerate(nums): # maintain decreasing order
# ```
#
# **218. Minimum Window Substring**
# *Hint: Expand right, shrink left.*
# ```python
# # expand r to satisfy, shrink l to optimize
# ```
#
# **219. Longest Substring Without Repeating**
# *Hint: Sliding window with set.*
# ```python
# l=0;
# for r in range(n):
#     while s[r] in window: window.remove(s[l]); l+=1
# ```
#
# **220. Substring with K Distinct Characters**
# *Hint: Dict to track counts.*
# ```python
# window={};
# for r in range(n): window[s[r]]+=1 # shrink if > k
# ```
#
# **221. Regular Expression Matching**
# *Hint: 2D DP.*
# ```python
# dp[i][j] = dp[i-1][j-1] if match else # handle '*'
# ```
#
# **222. Wildcard Matching**
# *Hint: DP, '*' matches empty or sequence.*
# ```python
# dp[i][j] = dp[i-1][j-1] or dp[i-1][j] if c=='*'
# ```
#
# **223. Decode Ways**
# *Hint: DP similar to Fibonacci.*
# ```python
# dp[i] = dp[i-1] + dp[i-2] if valid 2-digit
# ```
#
# **224. Unique Paths**
# *Hint: 2D DP grid.*
# ```python
# dp[i][j] = dp[i-1][j] + dp[i][j-1]
# ```
#
# **225. Unique Paths with Obstacles**
# *Hint: DP, set to 0 if obstacle.*
# ```python
# if grid[i][j]==1: dp[i][j]=0
# ```
#
# **226. Minimum Path Sum**
# *Hint: DP, add min of top/left.*
# ```python
# dp[i][j] = grid[i][j] + min(dp[i-1][j], dp[i][j-1])
# ```
#
# **227. Dungeon Game**
# *Hint: DP backwards from bottom-right.*
# ```python
# dp[i][j] = max(1, min(dp[i+1][j], dp[i][j+1]) - dungeon[i][j])
# ```
#
# **228. Best Time to Buy/Sell Stock**
# *Hint: Track min price and max profit.*
# ```python
# min_price=inf; max_prof=0;
# for p in prices: # update both
# ```
#
# **229. Stock with Cooldown**
# *Hint: State machine DP.*
# ```python
# # hold, sold, rest states
# ```
#
# **230. Burst Balloons**
# *Hint: Interval DP.*
# ```python
# dp[i][j] = max(dp[i][k-1] + dp[k+1][j] + nums[i-1]*nums[k]*nums[j+1])
# ```
#
# **231. N-Queens**
# *Hint: Backtracking with sets for cols/diags.*
# ```python
# cols, diag1, diag2 = set(), set(), set();
# def backtrack(row): pass
# ```
#
# **232. Sudoku Solver**
# *Hint: Backtracking with row/col/box sets.*
# ```python
# rows, cols, boxes = set(), set(), set();
# def solve(i,j): pass
# ```
#
# **233. Word Search**
# *Hint: DFS on grid with visited set.*
# ```python
# def dfs(r,c,i):
#     if i==len(word): return True
# ```
#
# **234. Palindrome Partitioning**
# *Hint: Backtracking.*
# ```python
# def backtrack(start, path): # if end, add path to res
# ```
#
# **235. Permutations**
# *Hint: `itertools.permutations`.*
# ```python
# list(itertools.permutations(nums))
# ```
#
# **236. Combination Sum**
# *Hint: Backtracking with index.*
# ```python
# def dfs(target, path, idx): # recurse with same or next idx
# ```
#
# **237. Subsets**
# *Hint: Bitmasking or backtracking.*
# ```python
# for i in range(1<<n): # build subset from bits
# ```
#
# **238. Letter Combinations of Phone**
# *Hint: `itertools.product`.*
# ```python
# itertools.product(*[digits_map[d] for d in digits])
# ```
#
# **239. Generate Parentheses**
# *Hint: Backtrack tracking open/close counts.*
# ```python
# def gen(l, r, path):
#     if l==r==n: res.append(path)
# ```
#
# **240. Word Break II**
# *Hint: Memoized DFS.*
# ```python
# @lru_cache;
# def dfs(s): # return list of sentences
# ```
#
# **241. Implement Trie**
# *Hint: Class with dict children.*
# ```python
# class Trie: # insert, search, startsWith
# ```
#
# **242. Add and Search Word**
# *Hint: Trie + DFS for '.' wildcard.*
# ```python
# if c=='.': return any(dfs(child, i+1) for child in node.children.values())
# ```
#
# **243. Word Search II**
# *Hint: Build Trie of words, DFS on board.*
# ```python
# # build trie of words, dfs on board
# ```
#
# **244. Find Median from Data Stream**
# *Hint: Max-heap for lower, Min-heap for upper.*
# ```python
# max_heap, min_heap = [], [] # balance sizes
# ```
#
# **245. Kth Smallest in BST**
# *Hint: Inorder traversal generator.*
# ```python
# def inorder(node):
#     yield from inorder(node.left); yield node.val
# ```
#
# **246. Serialize N-ary Tree**
# *Hint: Store children count.*
# ```python
# # store children count or null markers
# ```
#
# **247. Lowest Common Ancestor**
# *Hint: Recursive split.*
# ```python
# if not root or root in (p,q): return root
# ```
#
# **248. Max Depth Binary Tree**
# *Hint: Recursive 1 + max.*
# ```python
# return 1 + max(maxDepth(l), maxDepth(r))
# ```
#
# **249. Invert Binary Tree**
# *Hint: Swap left and right recursively.*
# ```python
# root.left, root.right = invert(r), invert(l)
# ```
#
# **250. Symmetric Tree**
# *Hint: Compare left subtree to right subtree.*
# ```python
# def check(l, r): return l.val==r.val and check(l.left, r.right)
# ```
#
# **251. Count Univalue Subtrees**
# *Hint: Postorder returning boolean and count.*
# ```python
# return is_uni, count
# ```
#
# **252. Flatten Bin Tree to Linked List**
# *Hint: Preorder traversal stack.*
# ```python
# stack=[root];
# while stack: # pop, push right, push left
# ```
#
# **253. Populating Next Right Pointers**
# *Hint: BFS level by level.*
# ```python
# # use dummy head for next level
# ```
#
# **254. Bin Tree Max Path Sum**
# *Hint: Postorder returning max gain down.*
# ```python
# max_gain(node) # returns max path down, updates global max
# ```
#
# **255. Sum Root to Leaf Numbers**
# *Hint: DFS passing current sum.*
# ```python
# def dfs(node, curr): curr = curr*10 + node.val
# ```
#
# **256. BST Iterator**
# *Hint: Stack of left children.*
# ```python
# stack=[];
# # push all left children initially
# ```
#
# **257. Kth Smallest in Matrix**
# *Hint: Min-heap of first column.*
# ```python
# # push first col, pop and push right neighbor
# ```
#
# **258. Find Peak Element**
# *Hint: Binary search comparing mid to mid+1.*
# ```python
# if nums[mid] < nums[mid+1]: l = mid+1
# ```
#
# **259. Search in Rotated Sorted Array**
# *Hint: Identify sorted half.*
# ```python
# # identify sorted half, check if target in it
# ```
#
# **260. Find Min in Rotated Sorted**
# *Hint: Compare mid to right.*
# ```python
# if nums[mid] > nums[r]: l = mid+1
# ```
#
# **261. Median of Two Sorted Arrays**
# *Hint: O(log(min(N,M))) binary search.*
# ```python
# # O(log(min(N,M))) partition
# ```
#
# **262. Sqrt(x)**
# *Hint: Binary search 0 to x.*
# ```python
# l, r = 0, x;
# while l<=r: # standard bin search
# ```
#
# **263. Search 2D Matrix**
# *Hint: Treat as 1D array.*
# ```python
# # treat as 1D array of size M*N
# ```
#
# **264. Search 2D Matrix II**
# *Hint: Start top-right, go left or down.*
# ```python
# # start top-right, go left or down
# ```
#
# **265. Find First and Last Position**
# *Hint: `bisect_left` and `bisect_right`.*
# ```python
# import bisect; bisect_left(a, t), bisect_right(a, t)-1
# ```
#
# **266. Single Element in Sorted Array**
# *Hint: Binary search checking even/odd indices.*
# ```python
# # check even/odd indices
# ```
#
# **267. Capacity To Ship Packages**
# *Hint: Binary search the answer.*
# ```python
# # binary search on capacity range
# ```
#
# **268. Split Array Largest Sum**
# *Hint: Binary search the max subarray sum.*
# ```python
# # binary search on max subarray sum
# ```
#
# **269. Koko Eating Bananas**
# *Hint: Binary search speed k.*
# ```python
# # binary search on speed k
# ```
#
# **270. Min Days to Make Bouquets**
# *Hint: Binary search days.*
# ```python
# # binary search on days
# ```
#
# **271. Union Find (Disjoint Set)**
# *Hint: Path compression and union by rank.*
# ```python
# parent, rank = {}, {};
# def find(x): # path compression
# ```
#
# **272. Number of Islands**
# *Hint: DFS/BFS to sink islands.*
# ```python
# for i,j:
#     if grid=='1': dfs(i,j); count+=1
# ```
#
# **273. Surrounded Regions**
# *Hint: DFS from borders, flip rest.*
# ```python
# # mark 'O' on border, flip rest to 'X'
# ```
#
# **274. Clone Graph**
# *Hint: DFS with visited dictionary.*
# ```python
# visited = {} # map old to new nodes
# ```
#
# **275. Pacific Atlantic Water Flow**
# *Hint: DFS from both oceans, intersect.*
# ```python
# # two sets of reachable cells, intersect
# ```
#
# **276. Course Schedule II**
# *Hint: Kahn's algorithm.*
# ```python
# # Kahn's algo, return order or []
# ```
#
# **277. Reconstruct Itinerary**
# *Hint: Hierholzer's algorithm (Eulerian path).*
# ```python
# # postorder DFS, reverse result
# ```
#
# **278. Network Delay Time**
# *Hint: Dijkstra tracking max time.*
# ```python
# # min heap, track max time to reach all
# ```
#
# **279. Word Ladder**
# *Hint: BFS with visited set.*
# ```python
# # queue, visited set, transform one char
# ```
#
# **280. Minimum Spanning Tree**
# *Hint: Kruskal's with Union-Find.*
# ```python
# # sort edges, union-find
# ```
#
# **281. Dijkstra's Algorithm**
# *Hint: Min-heap priority queue.*
# ```python
# dist = [inf]*n; pq=[(0, start)]
# ```
#
# **282. Bellman-Ford**
# *Hint: Relax edges V-1 times.*
# ```python
# for _ in range(V-1):
#     for u,v,w in edges: # relax
# ```
#
# **283. Floyd-Warshall**
# *Hint: 3 nested loops.*
# ```python
# dist[i][j] = min(dist[i][j], dist[i][k]+dist[k][j])
# ```
#
# **284. Topological Sort**
# *Hint: Indegree array and queue.*
# ```python
# # indegree array, queue
# ```
#
# **285. Bipartite Graph**
# *Hint: BFS 2-coloring.*
# ```python
# # color array, 0/1, check neighbors
# ```
#
# **286. Detect Cycle Directed**
# *Hint: DFS with 3 states.*
# ```python
# # 0=unvisited, 1=visiting, 2=visited
# ```
#
# **287. Detect Cycle Undirected**
# *Hint: Union-Find.*
# ```python
# if find(u)==find(v): return True # cycle
# ```
#
# **288. Strongly Connected Components**
# *Hint: Kosaraju's algorithm.*
# ```python
# # DFS1, reverse graph, DFS2
# ```
#
# **289. Articulation Points**
# *Hint: Tarjan's algorithm.*
# ```python
# # discovery time, low link values
# ```
#
# **290. Bridges in Graph**
# *Hint: Tarjan's condition.*
# ```python
# if low[v] > disc[u]: # bridge found
# ```
#
# **291. Max Flow (Ford-Fulkerson)**
# *Hint: Edmonds-Karp (BFS for paths).*
# ```python
# # residual graph, augmenting paths
# ```
#
# **292. Min Cost Max Flow**
# *Hint: Successive shortest paths.*
# ```python
# # Bellman-Ford/SPFA for shortest paths
# ```
#
# **293. Bipartite Matching**
# *Hint: Hopcroft-Karp algorithm.*
# ```python
# # BFS layers, DFS augmenting paths
# ```
#
# **294. Stable Marriage**
# *Hint: Gale-Shapley algorithm.*
# ```python
# # proposals, free men queue
# ```
#
# **295. Chinese Postman Problem**
# *Hint: Pair odd degree vertices.*
# ```python
# # pair odd degree vertices, shortest paths
# ```
#
# **296. Traveling Salesperson**
# *Hint: DP with bitmask.*
# ```python
# dp[mask][i] = min cost to visit mask ending at i
# ```
#
# **297. Vehicle Routing Problem**
# *Hint: Heuristics or OR-Tools.*
# ```python
# # clarke-wright savings, or-tools
# ```
#
# **298. Graph Coloring**
# *Hint: Backtracking or DSATUR.*
# ```python
# # assign colors, check neighbors
# ```
#
# **299. Maximum Independent Set**
# *Hint: DP on trees or branch and bound.*
# ```python
# # include/exclude node
# ```
#
# **300. Vertex Cover**
# *Hint: 2-approximation via matching.*
# ```python
# # 2-approximation via maximal matching
# ```
